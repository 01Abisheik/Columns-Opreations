# %% [markdown]
# ## COLUMN OPERATIONS

# %%
import pandas as pd
import matplotlib.pyplot as mat
import seaborn as sea

# %% [markdown]
# ##### Importing the libraries pandas ,matplotlib.pyplot an seaborn from python, in order to perform column operations on the dataset

# %%
sample = pd.read_csv("F:/Abi/python/python data/BIKE kaggle.csv")

# %%
sample
# Out:
#                                      name  selling_price  year seller_type  \
# 0               Royal Enfield Classic 350         175000  2019  Individual
# 1                               Honda Dio          45000  2017  Individual
# 2     Royal Enfield Classic Gunmetal Grey         150000  2018  Individual
# 3       Yamaha Fazer FI V 2.0 [2016-2018]          65000  2015  Individual
# 4                   Yamaha SZ [2013-2014]          20000  2011  Individual
# ...                                   ...            ...   ...         ...
# 1056                            Activa 3g          17000  2010  Individual
# 1057                     Honda CB twister          16000  2012  Individual
# 1058                   Bajaj Discover 125          15000  2013  Individual
# 1059                       Honda CB Shine          12000  2009  Individual
# 1060                     Bajaj Pulsar 150          10000  2008  Individual
#
#           owner  km_driven  ex_showroom_price quality
# ...

# %%
sample.columns
# Out:
# Index(['name', 'selling_price', 'year', 'seller_type', 'owner', 'km_driven',
#        'ex_showroom_price', 'quality'],
#       dtype='object')

# %% [markdown]
# ##### Displaying the variable names in the dataset.

# %%
sample['total']=sample['selling_price']+sample['ex_showroom_price']

# %% [markdown]
# ##### Added a new variable in the dataset by combining the variables selling_price and ex_showroom_price

# %%
sample
# Out:
#                                      name  selling_price  year seller_type  \
# 0               Royal Enfield Classic 350         175000  2019  Individual
# 1                               Honda Dio          45000  2017  Individual
# 2     Royal Enfield Classic Gunmetal Grey         150000  2018  Individual
# 3       Yamaha Fazer FI V 2.0 [2016-2018]          65000  2015  Individual
# 4                   Yamaha SZ [2013-2014]          20000  2011  Individual
# ...                                   ...            ...   ...         ...
# 1056                            Activa 3g          17000  2010  Individual
# 1057                     Honda CB twister          16000  2012  Individual
# 1058                   Bajaj Discover 125          15000  2013  Individual
# 1059                       Honda CB Shine          12000  2009  Individual
# 1060                     Bajaj Pulsar 150          10000  2008  Individual
#
#           owner  km_driven  ex_showroom_price quality     total
# ...

# %%
sample['low']=sample['selling_price']/sample['ex_showroom_price']

# %%
sample
# Out:
#                                      name  selling_price  year seller_type  \
# 0               Royal Enfield Classic 350         175000  2019  Individual
# 1                               Honda Dio          45000  2017  Individual
# 2     Royal Enfield Classic Gunmetal Grey         150000  2018  Individual
# 3       Yamaha Fazer FI V 2.0 [2016-2018]          65000  2015  Individual
# 4                   Yamaha SZ [2013-2014]          20000  2011  Individual
# ...                                   ...            ...   ...         ...
# 1056                            Activa 3g          17000  2010  Individual
# 1057                     Honda CB twister          16000  2012  Individual
# 1058                   Bajaj Discover 125          15000  2013  Individual
# 1059                       Honda CB Shine          12000  2009  Individual
# 1060                     Bajaj Pulsar 150          10000  2008  Individual
#
# ...

# %%
sample.rename(columns={'selling_price':'Sales'})
# Out:
#                                      name   Sales  year seller_type  \
# 0               Royal Enfield Classic 350  175000  2019  Individual
# 1                               Honda Dio   45000  2017  Individual
# 2     Royal Enfield Classic Gunmetal Grey  150000  2018  Individual
# 3       Yamaha Fazer FI V 2.0 [2016-2018]   65000  2015  Individual
# 4                   Yamaha SZ [2013-2014]   20000  2011  Individual
# ...                                   ...     ...   ...         ...
# 1056                            Activa 3g   17000  2010  Individual
# 1057                     Honda CB twister   16000  2012  Individual
# 1058                   Bajaj Discover 125   15000  2013  Individual
# 1059                       Honda CB Shine   12000  2009  Individual
# 1060                     Bajaj Pulsar 150   10000  2008  Individual
#
#           owner  km_driven  ex_showroom_price quality     total       low
# 0     1st owner        350                NaN    good       NaN       NaN
# ...

# %% [markdown]
# ##### Renamed a 'selling_price' variablselling_price as 'Sales'

# %%
sample.rename(columns={'ex_showroom_price':'Original Price','total':'final'})
# Out:
#                                      name  selling_price  year seller_type  \
# 0               Royal Enfield Classic 350         175000  2019  Individual
# 1                               Honda Dio          45000  2017  Individual
# 2     Royal Enfield Classic Gunmetal Grey         150000  2018  Individual
# 3       Yamaha Fazer FI V 2.0 [2016-2018]          65000  2015  Individual
# 4                   Yamaha SZ [2013-2014]          20000  2011  Individual
# ...                                   ...            ...   ...         ...
# 1056                            Activa 3g          17000  2010  Individual
# 1057                     Honda CB twister          16000  2012  Individual
# 1058                   Bajaj Discover 125          15000  2013  Individual
# 1059                       Honda CB Shine          12000  2009  Individual
# 1060                     Bajaj Pulsar 150          10000  2008  Individual
#
# ...

# %% [markdown]
# ##### Renamed Two variables 'ex_showroom_price' as 'Original Price' and 'total' as 'final'.

# %%
sample.drop(['seller_type','km_driven'],axis=1)
# Out:
#                                      name  selling_price  year      owner  \
# 0               Royal Enfield Classic 350         175000  2019  1st owner
# 1                               Honda Dio          45000  2017  1st owner
# 2     Royal Enfield Classic Gunmetal Grey         150000  2018  1st owner
# 3       Yamaha Fazer FI V 2.0 [2016-2018]          65000  2015  1st owner
# 4                   Yamaha SZ [2013-2014]          20000  2011  2nd owner
# ...                                   ...            ...   ...        ...
# 1056                            Activa 3g          17000  2010  1st owner
# 1057                     Honda CB twister          16000  2012  1st owner
# 1058                   Bajaj Discover 125          15000  2013  2nd owner
# 1059                       Honda CB Shine          12000  2009  1st owner
# 1060                     Bajaj Pulsar 150          10000  2008  1st owner
#
#       ex_showroom_price quality     total       low
# ...

# %% [markdown]
# ##### We have dropped the variables 'seller_type' and 'km_driven' from the dataset

# %%
sample.columns=[col.upper()for col in sample.columns]

# %%
sample
# Out:
#                                      NAME  SELLING_PRICE  YEAR SELLER_TYPE  \
# 0               Royal Enfield Classic 350         175000  2019  Individual
# 1                               Honda Dio          45000  2017  Individual
# 2     Royal Enfield Classic Gunmetal Grey         150000  2018  Individual
# 3       Yamaha Fazer FI V 2.0 [2016-2018]          65000  2015  Individual
# 4                   Yamaha SZ [2013-2014]          20000  2011  Individual
# ...                                   ...            ...   ...         ...
# 1056                            Activa 3g          17000  2010  Individual
# 1057                     Honda CB twister          16000  2012  Individual
# 1058                   Bajaj Discover 125          15000  2013  Individual
# 1059                       Honda CB Shine          12000  2009  Individual
# 1060                     Bajaj Pulsar 150          10000  2008  Individual
#
# ...

# %% [markdown]
# ##### Displayed the Variables name of the dataset in the Uppercase.

# %%
sample.columns=[col.lower()for col in sample.columns]

# %%
sample
# Out:
#                                      name  selling_price  year seller_type  \
# 0               Royal Enfield Classic 350         175000  2019  Individual
# 1                               Honda Dio          45000  2017  Individual
# 2     Royal Enfield Classic Gunmetal Grey         150000  2018  Individual
# 3       Yamaha Fazer FI V 2.0 [2016-2018]          65000  2015  Individual
# 4                   Yamaha SZ [2013-2014]          20000  2011  Individual
# ...                                   ...            ...   ...         ...
# 1056                            Activa 3g          17000  2010  Individual
# 1057                     Honda CB twister          16000  2012  Individual
# 1058                   Bajaj Discover 125          15000  2013  Individual
# 1059                       Honda CB Shine          12000  2009  Individual
# 1060                     Bajaj Pulsar 150          10000  2008  Individual
#
# ...

# %% [markdown]
# ##### Displayed the Variables name of the dataset in the lowercase

# %%
sample.sort_values(by=['selling_price','ex_showroom_price'],ascending=[True,False])
# Out:
#                                name  selling_price  year seller_type  \
# 543                       TVS Excel           5000  1998  Individual
# 748        Honda Activa [2000-2015]           6000  2006  Individual
# 567                     Bajaj Super           6000  1991  Individual
# 77                        Honda Dio           7500  2009  Individual
# 115         Hero Honda Passion Plus           7500  2004  Individual
# ..                              ...            ...   ...         ...
# 311      Harley-Davidson Street 750         330000  2014  Individual
# 13                    Yamaha YZF R3         365000  2019  Individual
# 289  Kawasaki Ninja 650 [2018-2019]         425000  2017  Individual
# 134      Harley-Davidson Street Bob         750000  2013  Individual
# 295                 Suzuki GSX S750         760000  2019  Individual
#
#          owner  km_driven  ex_showroom_price quality      total       low
# ...

# %% [markdown]
# ##### In this we have sorted two variables 'selling_price' and 'ex_showroom_price' and then we have arranged the variable 'selling_price' in the ascending order.

# %%
sample.sort_values(by='total',ascending=True)
# Out:
#                            name  selling_price  year seller_type      owner  \
# 1055              Bajaj  ct 100          18000  2017  Individual  1st owner
# 748    Honda Activa [2000-2015]           6000  2006  Individual  2nd owner
# 906                    Yo Style          20000  2011  Individual  1st owner
# 456    Honda Activa [2000-2015]          10000  2009  Individual  1st owner
# 851                  TVS XL 100          30000  2017  Individual  1st owner
# ...                         ...            ...   ...         ...        ...
# 951   Royal Enfield Electra 5 S          90000  2012  Individual  1st owner
# 952             Hero Honda Hunk          20000  2010  Individual  1st owner
# 957      Bajaj Pulsar 220 DTS-i          60000  2014  Individual  1st owner
# 958      Hero Honda CBZ extreme          40000  2009  Individual  1st owner
# 959      Hero Honda CBZ extreme          35000  2012  Individual  1st owner
#
# ...

# %% [markdown]
# ##### Sorted the variable named 'total' and arranged its values in ascending order

# %%
sample.sort_values(by='total')
# Out:
#                            name  selling_price  year seller_type      owner  \
# 1055              Bajaj  ct 100          18000  2017  Individual  1st owner
# 748    Honda Activa [2000-2015]           6000  2006  Individual  2nd owner
# 906                    Yo Style          20000  2011  Individual  1st owner
# 456    Honda Activa [2000-2015]          10000  2009  Individual  1st owner
# 851                  TVS XL 100          30000  2017  Individual  1st owner
# ...                         ...            ...   ...         ...        ...
# 951   Royal Enfield Electra 5 S          90000  2012  Individual  1st owner
# 952             Hero Honda Hunk          20000  2010  Individual  1st owner
# 957      Bajaj Pulsar 220 DTS-i          60000  2014  Individual  1st owner
# 958      Hero Honda CBZ extreme          40000  2009  Individual  1st owner
# 959      Hero Honda CBZ extreme          35000  2012  Individual  1st owner
#
# ...

# %% [markdown]
# ##### We have sorted the variable named 'total'.

# %%
sample.drop(['low'],axis=1,inplace=True)

# %% [markdown]
# ##### We have dropped the variable named 'low' and used inplace function.

# %%
sample
# Out:
#                                      name  selling_price  year seller_type  \
# 0               Royal Enfield Classic 350         175000  2019  Individual
# 1                               Honda Dio          45000  2017  Individual
# 2     Royal Enfield Classic Gunmetal Grey         150000  2018  Individual
# 3       Yamaha Fazer FI V 2.0 [2016-2018]          65000  2015  Individual
# 4                   Yamaha SZ [2013-2014]          20000  2011  Individual
# ...                                   ...            ...   ...         ...
# 1056                            Activa 3g          17000  2010  Individual
# 1057                     Honda CB twister          16000  2012  Individual
# 1058                   Bajaj Discover 125          15000  2013  Individual
# 1059                       Honda CB Shine          12000  2009  Individual
# 1060                     Bajaj Pulsar 150          10000  2008  Individual
#
#           owner  km_driven  ex_showroom_price quality     total
# ...

# %%
sample.groupby('selling_price').count()
# Out:
#                name  year  seller_type  owner  km_driven  ex_showroom_price  \
# selling_price
# 5000              1     1            1      1          1                  0
# 6000              2     2            2      2          2                  1
# 7500              2     2            2      2          2                  0
# 8000              3     3            3      3          3                  0
# 9000              1     1            1      1          1                  0
# ...             ...   ...          ...    ...        ...                ...
# 330000            1     1            1      1          1                  1
# 365000            1     1            1      1          1                  1
# 425000            1     1            1      1          1                  1
# 750000            1     1            1      1          1                  1
# 760000            1     1            1      1          1                  1
#
#                quality  total
# ...

# %% [markdown]
# ##### By Performing groupby function on selling_price variable and used count function it is displays us this variable takes place in 130 observations.

# %%
sample = pd.read_csv("F:/Abi/python/python data/BIKE kaggle.csv")

# %%
sample
# Out:
#                                      name  selling_price  year seller_type  \
# 0               Royal Enfield Classic 350         175000  2019  Individual
# 1                               Honda Dio          45000  2017  Individual
# 2     Royal Enfield Classic Gunmetal Grey         150000  2018  Individual
# 3       Yamaha Fazer FI V 2.0 [2016-2018]          65000  2015  Individual
# 4                   Yamaha SZ [2013-2014]          20000  2011  Individual
# ...                                   ...            ...   ...         ...
# 1056                            Activa 3g          17000  2010  Individual
# 1057                     Honda CB twister          16000  2012  Individual
# 1058                   Bajaj Discover 125          15000  2013  Individual
# 1059                       Honda CB Shine          12000  2009  Individual
# 1060                     Bajaj Pulsar 150          10000  2008  Individual
#
#           owner  km_driven  ex_showroom_price quality
# ...

# %%
print(sample['selling_price'].isnull().sum())
# Out:
# 0

# %% [markdown]
# ##### There is no  null values present in the 'selling_price' variable.

# %%
print(sample.columns.values)
# Out:
# ['name' 'selling_price' 'year' 'seller_type' 'owner' 'km_driven'
#  'ex_showroom_price' 'quality']

# %% [markdown]
# ##### Displayed the variables but by using print function
